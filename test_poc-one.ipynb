# %%
# %run /Users/g.anshuman@tcs.com/poc-one

# %%
import unittest
# Out:
# +-------------+----------+--------------------+------+----------+--------------+-----------+-----------+---+
# |   Account_No|      DATE| TRANSACTION_DETAILS|CHQ_NO|VALUE_DATE|WITHDRAWAL_AMT|DEPOSIT_AMT|BALANCE_AMT|  .|
# +-------------+----------+--------------------+------+----------+--------------+-----------+-----------+---+
# |409000611074'|2017-06-29|TRF FROM  Indiafo...|  null|2017-06-29|          null|  1000000.0|  1000000.0|  .|
# |409000611074'|2017-07-05|TRF FROM  Indiafo...|  null|2017-07-05|          null|  1000000.0|  2000000.0|  .|
# |409000611074'|2017-07-18|FDRL/INTERNAL FUN...|  null|2017-07-18|          null|   500000.0|  2500000.0|  .|
# |409000611074'|2017-08-01|TRF FRM  Indiafor...|  null|2017-08-01|          null|  3000000.0|  5500000.0|  .|
# |409000611074'|2017-08-16|FDRL/INTERNAL FUN...|  null|2017-08-16|          null|   500000.0|  6000000.0|  .|
# +-------------+----------+--------------------+------+----------+--------------+-----------+-----------+---+
# ...

# %%
class TestPOCOne(unittest.TestCase):
    
    def test_addTransactionAmountColumn(self):
        
        columns_original = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT"]
        data_original = [(1, "2017-06-29", "cheque", 1.0, "2017-06-29", None, 100, 100), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400), 
                (3, "2017-08-01", "upi", 3.0, "2017-08-01", None, 300, 600), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800)
               ]
        df_bank = spark.createDataFrame(data = data_original, schema = columns_original)
        
        df_bank.createOrReplaceTempView("bank")
        
        df_transformed = pocOne.addTransactionAmountColumn()
        
        columns_expected = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT"]
        data_expected = [(1, "2017-06-29", "cheque", 1.0, "2017-06-29", None, 100, 100, 100), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200), 
                (3, "2017-08-01", "upi", 3.0, "2017-08-01", None, 300, 600, 300), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400)
               ]
        df_expected = spark.createDataFrame(data = data_expected, schema = columns_expected)
        
        if df_transformed.schema != df_expected.schema:
            return False
        if df_transformed.collect() != df_expected.collect():
            return False
        return True
    
    
    
    def test_addTransactionTypeColumn(self):
        
        columns_original = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT"]
        data_original = [(1, "2017-06-29", "cheque", 1.0, "2017-06-29", None, 100, 100, 100), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200), 
                (3, "2017-08-01", "upi", 3.0, "2017-08-01", None, 300, 600, 300), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400)
               ]
        df_bank = spark.createDataFrame(data = data_original, schema = columns_original)
        
        df_bank.createOrReplaceTempView("bank")
        
        df_transformed = pocOne.addTransactionTypeColumn()
        
        columns_expected = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT", "TRANSACTION_TYPE"]
        data_expected = [(1, "2017-06-29", "cheque", 1.0, "2017-06-29", None, 100, 100, 100, "CR"), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200, "DR"), 
                (3, "2017-08-01", "upi", 3.0, "2017-08-01", None, 300, 600, 300, "CR"), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400, "DR")
               ]
        df_expected = spark.createDataFrame(data = data_expected, schema = columns_expected)
        
        if df_transformed.schema != df_expected.schema:
            return False
        if df_transformed.collect() != df_expected.collect():
            return False
        return True
    
    
    
    def test_getChequeTransactions(self):
        
        columns_original = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT", "TRANSACTION_TYPE"]
        data_original = [(1, "2017-06-29", "cheque", 1.0, "2017-06-29", None, 100, 100, 100, "CR"), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200, "DR"), 
                (3, "2017-08-01", "upi", 3.0, "2017-08-01", None, 300, 600, 300, "CR"), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400, "DR")
               ]
        df_bank = spark.createDataFrame(data = data_original, schema = columns_original)
        
        df_bank.createOrReplaceTempView("bank")
        
        df_transformed = pocOne.getChequeTransactions()
        
        columns_expected = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT", "TRANSACTION_TYPE"]
        data_expected = [(1, "2017-06-29", "cheque", 1.0, "2017-06-29", None, 100, 100, 100, "CR"), 
                (3, "2017-08-01", "upi", 3.0, "2017-08-01", None, 300, 600, 300, "CR"), 
               ]
        df_expected = spark.createDataFrame(data = data_expected, schema = columns_expected)
        
        if df_transformed.schema != df_expected.schema:
            return False
        if df_transformed.collect() != df_expected.collect():
            return False
        return True
    
    
    
    def test_getCRTransactions(self):
        
        columns_original = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT", "TRANSACTION_TYPE"]
        data_original = [(1, "2017-06-29", "cheque", 1, "2017-06-29", None, 100, 100, 100, "CR"), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200, "DR"), 
                (3, "2017-08-01", "upi", 3, "2017-08-01", None, 300, 600, 300, "CR"), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400, "DR")
               ]
        df_bank = spark.createDataFrame(data = data_original, schema = columns_original)
        
        df_bank.createOrReplaceTempView("bank")
        
        df_transformed = pocOne.getCRTransactions()
        
        columns_expected = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT", "TRANSACTION_TYPE"]
        data_expected = [(1, "2017-06-29", "cheque", 1, "2017-06-29", None, 100, 100, 100, "CR"),  
                (3, "2017-08-01", "upi", 3, "2017-08-01", None, 300, 600, 300, "CR")
               ]
        df_expected = spark.createDataFrame(data = data_expected, schema = columns_expected)
        
        if df_transformed.schema != df_expected.schema:
            return False
        if df_transformed.collect() != df_expected.collect():
            return False
        return True
    
    
    
    def test_getDRTransactions(self):
        
        columns_original = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT", "TRANSACTION_TYPE"]
        data_original = [(1, "2017-06-29", "cheque", 1, "2017-06-29", None, 100, 100, 100, "CR"), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200, "DR"), 
                (3, "2017-08-01", "upi", 3, "2017-08-01", None, 300, 600, 300, "CR"), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400, "DR")
               ]
        df_bank = spark.createDataFrame(data = data_original, schema = columns_original)
        
        df_bank.createOrReplaceTempView("bank")
        
        df_transformed = pocOne.getDRTransactions()
        
        columns_expected = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT", "TRANSACTION_TYPE"]
        data_expected = [(2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200, "DR"),  
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400, "DR")
               ]
        df_expected = spark.createDataFrame(data = data_expected, schema = columns_expected)
        
        if df_transformed.schema != df_expected.schema:
            return False
        if df_transformed.collect() != df_expected.collect():
            return False
        return True
    
    
    
    def test_getTotalDepositWithdrawal(self):
        
        columns_original = ["Account_No", "DATE", "TRANSACTION_DETAILS", "CHQ_NO", "VALUE_DATE", "WITHDRAWAL_AMT", "DEPOSIT_AMT", "BALANCE_AMT", "TRANSACTION_AMOUNT"]
        data_original = [(1, "2017-06-29", "cheque", 1.0, "2017-06-29", None, 100, 100, 100), 
                (2, "2017-07-05", "direct", None, "2017-07-05", 200, None, 400, 200), 
                (3, "2017-08-01", "upi", 3.0, "2017-08-01", None, 300, 600, 300), 
                (4, "2017-08-16", "cheque", None, "2017-08-16", 400, None, 800, 400)
               ]
        df_bank = spark.createDataFrame(data = data_original, schema = columns_original)
        
        df_bank.createOrReplaceTempView("bank")
        
        df_transformed = pocOne.getTotalDepositWithdrawal()
        
        columns_expected = ["Account_No", "TOTAL_DEPOSIT", "TOTAL_WITHDRAW"]
        data_expected = [(1, 100, None), 
                (2, None, 200), 
                (3, 300, None), 
                (4, None, 400)
               ]
        df_expected = spark.createDataFrame(data = data_expected, schema = columns_expected)
        
        if df_transformed.schema != df_expected.schema:
            return False
        if df_transformed.collect() != df_expected.collect():
            return False
        return True
    
      
        
testPOCOne = TestPOCOne()

# %%
testPOCOne.test_addTransactionAmountColumn()
testPOCOne.test_addTransactionTypeColumn()
# Out:
# Out[29]: True
